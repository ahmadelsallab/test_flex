# %% [markdown]
# # Usage
# More use cases under tests/test_experiment.py
#
# ## Log new experiment result
# In general any experiment is composed of:
# - meta_data: name, purpose, file, commit,...etc
# - config: mostly the hyperparameters, and any other configuration like the used features. For deep learning, config can be further divided into: data, model, optimizer, learning hyper parameters
# - results: metrics, best model file, comment,..etc

# %% [markdown]
# Suppose all your previous records are in 'results_old.csv'.
#
# And now you want to log a new experiment.

# %%
from ..flex.config import Configuration

exp_meta_data = {'name': 'experiment_1',
            'purpose': 'test my awesome model',
             'date': 'today',
            }

exp_config = {'model_arch': '100-100-100',
          'learning_rate': 0.0001,
          'epochs': 2,
          'optimizer': 'Adam',
         }

exp_results = {'val_acc': 0.95, 
         'F1': 0.92,
         'Comment': 'Best model'}

experiment = Configuration(csv_file='results_old.csv', meta_data=exp_meta_data, params=exp_config, performance=exp_results)

# %% [markdown]
# __Note that__
#
# you can add or remove experiment parameters. In that case, if you add a parameter, old records will have NaN for those. If you delete some parameters, they will remain in the old records, but will be NaN in the new logged one.

# %% [markdown]
# Now Write CSV of the results

# %%
experiment.to_csv('results.csv')

# %% [markdown]
# If you want to see the whole record:

# %%
experiment.df
# Out:
#                                               Name  \
# 0                                   CNN1D_LSTM_Big
# 1                                 CNN1D_LSTM_Small
# 2                                              NaN
# 3                        LSTM_Big model_Small data
# 4  LSTM_Small model_Small data binary_crossentropy
# 5    LSTM_Big model_Small data binary_crossentropy
# 6               CNN1D_LSTM_Big binary_crossentropy
# 7   LSTM_Huge model_Small data binary_crossentropy
# 8     LSTM_Huge model_Big data binary_crossentropy
# 9                                              NaN
#
#                                              Purpose  \
# 0                      Baseline CNN1D-LSTM Text only
# 1                         Small CNN1D-LSTM Text only
# 2                    Small data CNN1D-LSTM Text only
# 3                          Small data LSTM Text only
# 4    LSTM_Small model_Small data binary_crossentropy
# 5    LSTM_Small model_Small data binary_crossentropy
# 6  Baseline CNN1D-LSTM Text only binary_crossentropy
# 7     LSTM_Huge model_Small data binary_crossentropy
# 8       LSTM_Huge model_Big data binary_crossentropy
# 9                                                NaN
#
#                                        Description  \
# 0                                        Big model
# 1                                      Small model
# 2                             Big model Small data
# 3                                  LSTM Small data
# 4  LSTM_Small model_Small data binary_crossentropy
# 5  LSTM_Small model_Small data binary_crossentropy
# 6                    Big model binary_crossentropy
# 7   LSTM_Huge model_Small data binary_crossentropy
# 8     LSTM_Huge model_Big data binary_crossentropy
# 9                                              NaN
#
#                                   Run file Commit      Features  \
# 0  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 1  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 2  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 3                        jigsaw_lstm.ipynb      -  comment_text
# 4                        jigsaw_lstm.ipynb      -  comment_text
# 5                        jigsaw_lstm.ipynb      -  comment_text
# 6  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 7                        jigsaw_lstm.ipynb      -  comment_text
# 8                        jigsaw_lstm.ipynb      -  comment_text
# 9                                      NaN    NaN           NaN
#
#    Train_test_split       Size   maxlen  batch_size   ...    \
# 0               0.2  1804874.0      317       256.0   ...
# 1               0.2  1804874.0      317       256.0   ...
# 2               0.2    20000.0      317       256.0   ...
# 3               0.2    20000.0      317       256.0   ...
# 4               0.2    20000.0  317/220       256.0   ...
# 5               0.2    20000.0      317       256.0   ...
# 6               0.2    20000.0      317       256.0   ...
# 7               0.2    20000.0      317       256.0   ...
# 8               0.2  1804874.0      317       256.0   ...
# 9               NaN        NaN      NaN         NaN   ...
#
#                      Model file  \
# 0  jigsaw_cnn_lstm_text_only.h5
# 1                             -
# 2  jigsaw_cnn_lstm_text_only.h5
# 3              jigsaw_lstm_1.h5
# 4              jigsaw_lstm_1.h5
# 5              jigsaw_lstm_1.h5
# 6  jigsaw_cnn_lstm_text_only.h5
# 7              jigsaw_lstm_1.h5
# 8              jigsaw_lstm_1.h5
# 9                           NaN
#
#                                              Comment   date          name  \
# 0  Same as small. Couldnt overfitIssue in model t...    NaN           NaN
# 1                     No overfit. Needs bigger model    NaN           NaN
# 2                           Also, loss not improving    NaN           NaN
# 3        Loss decreasing slowly, then aslo saturates    NaN           NaN
# 4  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 5  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 6  Saturation as before \nBUT\nAccuracy improved ...    NaN           NaN
# 7  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 8  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 9                                         Best model  today  experiment_1
#
#                  purpose  learning_rate   model_arch optimizer    F1 val_acc
# 0                    NaN            NaN          NaN       NaN   NaN     NaN
# 1                    NaN            NaN          NaN       NaN   NaN     NaN
# 2                    NaN            NaN          NaN       NaN   NaN     NaN
# 3                    NaN            NaN          NaN       NaN   NaN     NaN
# 4                    NaN            NaN          NaN       NaN   NaN     NaN
# 5                    NaN            NaN          NaN       NaN   NaN     NaN
# 6                    NaN            NaN          NaN       NaN   NaN     NaN
# 7                    NaN            NaN          NaN       NaN   NaN     NaN
# 8                    NaN            NaN          NaN       NaN   NaN     NaN
# 9  test my awesome model         0.0001  100-100-100      Adam  0.92    0.95
#
# [10 rows x 32 columns]

# %% [markdown]
# ## Alternatively, you could init the Experiment with the old records, and later log one or more experiment

# %%
from ..flex.config import Configuration

# Load the old records
experiment = Configuration(csv_file='results_old.csv')

# TODO: perform you experiment

# Now log the new experiment data
exp_meta_data = {'name': 'experiment_1',
            'purpose': 'test my awesome model',
             'date': 'today',
            }

exp_config = {'model_arch': '100-100-100',
          'learning_rate': 0.0001,
          'epochs': 2,
          'optimizer': 'Adam',
         }

exp_results = {'val_acc': 0.95, 
         'F1': 0.92,
         'Comment': 'Best model'}

experiment.log(meta_data=exp_meta_data, params=exp_config, performance=exp_results)

# Export the whole result
experiment.to_csv('results.csv')

experiment.df
# Out:
#                                               Name  \
# 0                                   CNN1D_LSTM_Big
# 1                                 CNN1D_LSTM_Small
# 2                                              NaN
# 3                        LSTM_Big model_Small data
# 4  LSTM_Small model_Small data binary_crossentropy
# 5    LSTM_Big model_Small data binary_crossentropy
# 6               CNN1D_LSTM_Big binary_crossentropy
# 7   LSTM_Huge model_Small data binary_crossentropy
# 8     LSTM_Huge model_Big data binary_crossentropy
# 9                                              NaN
#
#                                              Purpose  \
# 0                      Baseline CNN1D-LSTM Text only
# 1                         Small CNN1D-LSTM Text only
# 2                    Small data CNN1D-LSTM Text only
# 3                          Small data LSTM Text only
# 4    LSTM_Small model_Small data binary_crossentropy
# 5    LSTM_Small model_Small data binary_crossentropy
# 6  Baseline CNN1D-LSTM Text only binary_crossentropy
# 7     LSTM_Huge model_Small data binary_crossentropy
# 8       LSTM_Huge model_Big data binary_crossentropy
# 9                                                NaN
#
#                                        Description  \
# 0                                        Big model
# 1                                      Small model
# 2                             Big model Small data
# 3                                  LSTM Small data
# 4  LSTM_Small model_Small data binary_crossentropy
# 5  LSTM_Small model_Small data binary_crossentropy
# 6                    Big model binary_crossentropy
# 7   LSTM_Huge model_Small data binary_crossentropy
# 8     LSTM_Huge model_Big data binary_crossentropy
# 9                                              NaN
#
#                                   Run file Commit      Features  \
# 0  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 1  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 2  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 3                        jigsaw_lstm.ipynb      -  comment_text
# 4                        jigsaw_lstm.ipynb      -  comment_text
# 5                        jigsaw_lstm.ipynb      -  comment_text
# 6  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 7                        jigsaw_lstm.ipynb      -  comment_text
# 8                        jigsaw_lstm.ipynb      -  comment_text
# 9                                      NaN    NaN           NaN
#
#    Train_test_split       Size   maxlen  batch_size   ...    \
# 0               0.2  1804874.0      317       256.0   ...
# 1               0.2  1804874.0      317       256.0   ...
# 2               0.2    20000.0      317       256.0   ...
# 3               0.2    20000.0      317       256.0   ...
# 4               0.2    20000.0  317/220       256.0   ...
# 5               0.2    20000.0      317       256.0   ...
# 6               0.2    20000.0      317       256.0   ...
# 7               0.2    20000.0      317       256.0   ...
# 8               0.2  1804874.0      317       256.0   ...
# 9               NaN        NaN      NaN         NaN   ...
#
#                      Model file  \
# 0  jigsaw_cnn_lstm_text_only.h5
# 1                             -
# 2  jigsaw_cnn_lstm_text_only.h5
# 3              jigsaw_lstm_1.h5
# 4              jigsaw_lstm_1.h5
# 5              jigsaw_lstm_1.h5
# 6  jigsaw_cnn_lstm_text_only.h5
# 7              jigsaw_lstm_1.h5
# 8              jigsaw_lstm_1.h5
# 9                           NaN
#
#                                              Comment   date          name  \
# 0  Same as small. Couldnt overfitIssue in model t...    NaN           NaN
# 1                     No overfit. Needs bigger model    NaN           NaN
# 2                           Also, loss not improving    NaN           NaN
# 3        Loss decreasing slowly, then aslo saturates    NaN           NaN
# 4  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 5  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 6  Saturation as before \nBUT\nAccuracy improved ...    NaN           NaN
# 7  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 8  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 9                                         Best model  today  experiment_1
#
#                  purpose  learning_rate   model_arch optimizer    F1 val_acc
# 0                    NaN            NaN          NaN       NaN   NaN     NaN
# 1                    NaN            NaN          NaN       NaN   NaN     NaN
# 2                    NaN            NaN          NaN       NaN   NaN     NaN
# 3                    NaN            NaN          NaN       NaN   NaN     NaN
# 4                    NaN            NaN          NaN       NaN   NaN     NaN
# 5                    NaN            NaN          NaN       NaN   NaN     NaN
# 6                    NaN            NaN          NaN       NaN   NaN     NaN
# 7                    NaN            NaN          NaN       NaN   NaN     NaN
# 8                    NaN            NaN          NaN       NaN   NaN     NaN
# 9  test my awesome model         0.0001  100-100-100      Adam  0.92    0.95
#
# [10 rows x 32 columns]

# %% [markdown]
# ## You can init an emtpy experiment, or with a certain csv, and add or change the old records csv.
#
# __But in this case, the records will be modified not appended or updated.__

# %%
from ..flex.config import Configuration

# Init empty experiment
experiment = Configuration() # or Experiment(csv_file="another_results.csv")

# Update with another
experiment.from_csv(csv_file='results_old.csv')

# Now log the new experiment data
exp_meta_data = {'name': 'experiment_1',
            'purpose': 'test my awesome model',
             'date': 'today',
            }

exp_config = {'model_arch': '100-100-100',
          'learning_rate': 0.0001,
          'epochs': 2,
          'optimizer': 'Adam',
         }

exp_results = {'val_acc': 0.95, 
         'F1': 0.92,
         'Comment': 'Best model',}

experiment.log(meta_data=exp_meta_data, params=exp_config, performance=exp_results)

# Export the whole result
experiment.to_csv('results.csv')

experiment.df
# Out:
# /home/ahmad/anaconda3/lib/python3.6/site-packages/mllogger/experiments.py:33: UserWarning: No old experiments records given. It's OK if this is the first record or you will add later using from_csv or from_df. Otherwise, old records they will be overwritten
#   warnings.warn(UserWarning("No old experiments records given. It's OK if this is the first record or you will add later using from_csv or from_df. Otherwise, old records they will be overwritten"))
#                                               Name  \
# 0                                   CNN1D_LSTM_Big
# 1                                 CNN1D_LSTM_Small
# 2                                              NaN
# 3                        LSTM_Big model_Small data
# 4  LSTM_Small model_Small data binary_crossentropy
# 5    LSTM_Big model_Small data binary_crossentropy
# 6               CNN1D_LSTM_Big binary_crossentropy
# 7   LSTM_Huge model_Small data binary_crossentropy
# 8     LSTM_Huge model_Big data binary_crossentropy
# 9                                              NaN
#
#                                              Purpose  \
# 0                      Baseline CNN1D-LSTM Text only
# 1                         Small CNN1D-LSTM Text only
# 2                    Small data CNN1D-LSTM Text only
# 3                          Small data LSTM Text only
# 4    LSTM_Small model_Small data binary_crossentropy
# 5    LSTM_Small model_Small data binary_crossentropy
# 6  Baseline CNN1D-LSTM Text only binary_crossentropy
# 7     LSTM_Huge model_Small data binary_crossentropy
# 8       LSTM_Huge model_Big data binary_crossentropy
# 9                                                NaN
#
#                                        Description  \
# 0                                        Big model
# 1                                      Small model
# 2                             Big model Small data
# 3                                  LSTM Small data
# 4  LSTM_Small model_Small data binary_crossentropy
# 5  LSTM_Small model_Small data binary_crossentropy
# 6                    Big model binary_crossentropy
# 7   LSTM_Huge model_Small data binary_crossentropy
# 8     LSTM_Huge model_Big data binary_crossentropy
# 9                                              NaN
#
#                                   Run file Commit      Features  \
# 0  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 1  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 2  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 3                        jigsaw_lstm.ipynb      -  comment_text
# 4                        jigsaw_lstm.ipynb      -  comment_text
# 5                        jigsaw_lstm.ipynb      -  comment_text
# 6  jigsaw_simple_text_lstm_tokenizer.ipynb      -  comment_text
# 7                        jigsaw_lstm.ipynb      -  comment_text
# 8                        jigsaw_lstm.ipynb      -  comment_text
# 9                                      NaN    NaN           NaN
#
#    Train_test_split       Size   maxlen  batch_size   ...    \
# 0               0.2  1804874.0      317       256.0   ...
# 1               0.2  1804874.0      317       256.0   ...
# 2               0.2    20000.0      317       256.0   ...
# 3               0.2    20000.0      317       256.0   ...
# 4               0.2    20000.0  317/220       256.0   ...
# 5               0.2    20000.0      317       256.0   ...
# 6               0.2    20000.0      317       256.0   ...
# 7               0.2    20000.0      317       256.0   ...
# 8               0.2  1804874.0      317       256.0   ...
# 9               NaN        NaN      NaN         NaN   ...
#
#                      Model file  \
# 0  jigsaw_cnn_lstm_text_only.h5
# 1                             -
# 2  jigsaw_cnn_lstm_text_only.h5
# 3              jigsaw_lstm_1.h5
# 4              jigsaw_lstm_1.h5
# 5              jigsaw_lstm_1.h5
# 6  jigsaw_cnn_lstm_text_only.h5
# 7              jigsaw_lstm_1.h5
# 8              jigsaw_lstm_1.h5
# 9                           NaN
#
#                                              Comment   date          name  \
# 0  Same as small. Couldnt overfitIssue in model t...    NaN           NaN
# 1                     No overfit. Needs bigger model    NaN           NaN
# 2                           Also, loss not improving    NaN           NaN
# 3        Loss decreasing slowly, then aslo saturates    NaN           NaN
# 4  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 5  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 6  Saturation as before \nBUT\nAccuracy improved ...    NaN           NaN
# 7  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 8  Accuracy improved a lot. The targets have lots...    NaN           NaN
# 9                                         Best model  today  experiment_1
#
#                  purpose  learning_rate   model_arch optimizer    F1 val_acc
# 0                    NaN            NaN          NaN       NaN   NaN     NaN
# 1                    NaN            NaN          NaN       NaN   NaN     NaN
# 2                    NaN            NaN          NaN       NaN   NaN     NaN
# 3                    NaN            NaN          NaN       NaN   NaN     NaN
# 4                    NaN            NaN          NaN       NaN   NaN     NaN
# 5                    NaN            NaN          NaN       NaN   NaN     NaN
# 6                    NaN            NaN          NaN       NaN   NaN     NaN
# 7                    NaN            NaN          NaN       NaN   NaN     NaN
# 8                    NaN            NaN          NaN       NaN   NaN     NaN
# 9  test my awesome model         0.0001  100-100-100      Adam  0.92    0.95
#
# [10 rows x 32 columns]

# %% [markdown]
# ## Other use cases
#
# - You can load old records from pandas.DataFrame instead of csv using orig_df in the Experiment constructor
# ```
# df = pd.read_csv('results.old.csv')
# experiment = Experiment(orig_df=df)
# ```
#
# - You can log experiment using yaml files, either in init or using ```from_yaml``` method

# %% [markdown]
# # Known issues
#
# https://github.com/ahmadelsallab/logger/issues

# %% [markdown]
# # Future developments
# - JSON Support
# - xlsx support
# - The model checkpoints
# - Different visualizations and curves
# - Upload the result file to gdrive for online updates and sharing
